# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
linearRegression = LinearRegression()

# %%
df = pd.read_csv("/content/pokemon.csv")

# %%
df.head()
# Out:
#          Name Type 1  Type 2  Combat Power  HP  Attack  Defense  Sp. Atk  \
# 0   Bulbasaur  Grass  Poison           318  45      49       49       65
# 1     Ivysaur  Grass  Poison           405  60      62       63       80
# 2    Venusaur  Grass  Poison           525  80      82       83      100
# 3  Charmander   Fire     NaN           309  39      52       43       60
# 4  Charmeleon   Fire     NaN           405  58      64       58       80
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3       50     65           1      False
# 4       65     80           1      False

# %%
df.tail()
# Out:
#           Name   Type 1  Type 2  Combat Power   HP  Attack  Defense  Sp. Atk  \
# 146    Dratini   Dragon     NaN           300   41      64       45       50
# 147  Dragonair   Dragon     NaN           420   61      84       65       70
# 148  Dragonite   Dragon  Flying           600   91     134       95      100
# 149     Mewtwo  Psychic     NaN           680  106     110       90      154
# 150        Mew  Psychic     NaN           600  100     100      100      100
#
#      Sp. Def  Speed  Generation  Legendary
# 146       50     50           1      False
# 147       70     70           1      False
# 148      100     80           1      False
# 149       90    130           1       True
# 150      100    100           1       True

# %%
var = [x for x in df.columns if x not in "Power"]

# %%
len(var)
# Out:
# 12

# %%
variables = ["Name","Type 1","Type 2"]

# %%
df = pd.get_dummies(data = df, prefix = variables, columns = variables)

# %%
df.head()
# Out:
#    Combat Power  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# 0           318  45      49       49       65       65     45           1
# 1           405  60      62       63       80       80     60           1
# 2           525  80      82       83      100      100     80           1
# 3           309  39      52       43       60       50     65           1
# 4           405  58      64       58       80       65     80           1
#
#    Legendary  Name_Abra  ...  Type 2_Fighting  Type 2_Flying  Type 2_Grass  \
# 0      False      False  ...            False          False         False
# 1      False      False  ...            False          False         False
# 2      False      False  ...            False          False         False
# 3      False      False  ...            False          False         False
# 4      False      False  ...            False          False         False
#
# ...

# %%
var = [x for x in df.columns if x not in "Combat Power"]

# %%
len(var)
# Out:
# 185

# %%
X_train,X_test,y_train,y_test = train_test_split(df[var],df["Combat Power"],random_state = 55 , train_size = 0.8)

# %%
y_train
# Out:
# 68     300
# 41     455
# 109    490
# 57     350
# 99     330
#       ...
# 37     505
# 55     305
# 29     365
# 125    495
# 39     435
# Name: Combat Power, Length: 120, dtype: int64

# %%
linearRegression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
linearRegression.coef_
# Out:
# array([ 9.95891634e-01,  1.00702206e+00,  9.92158291e-01,  1.00653171e+00,
#         1.00067324e+00,  9.87851734e-01, -7.77156117e-16,  2.76757546e-01,
#        -1.60164665e-01,  2.95416326e-01,  1.29242637e-01,  1.50816762e-01,
#         1.56831083e-01, -3.04133627e-02, -7.12169010e-02, -3.86521061e-01,
#         2.22044605e-16, -4.48689050e-02, -1.94289029e-16, -3.33066907e-16,
#         6.51420895e-01,  1.31740747e-01, -1.85413946e-02,  1.34369566e-01,
#        -4.39790093e-03,  0.00000000e+00, -9.71445147e-17, -3.50926280e-02,
#         8.69226783e-02, -1.85364804e-02, -2.14058187e-01, -2.36276665e-02,
#        -2.70410767e-01,  1.03670177e-01, -1.24866586e-01, -9.37563030e-02,
#        -1.79452547e-01,  2.93563724e-01, -1.25582776e-01, -1.94289029e-16,
#         1.05778243e+00, -7.98107528e+00,  1.33226763e-15, -4.44089210e-16,
#        -3.32341051e-01,  9.09419340e-02, -5.95140166e-01, -1.18621140e-01,
# ...

# %%
linearRegression.intercept_
# Out:
# 0.5277824939507809

# %%
linearRegression.predict(X_test)
# Out:
# array([194.966149  , 320.30782831, 315.41331909, 529.88685323,
#        275.02042886, 464.43460929, 300.53352229, 251.23901199,
#        324.76706416, 323.1858639 , 409.8500275 , 195.01158179,
#        454.96393038, 385.19416198, 454.75941751, 355.25582105,
#        288.09596634, 490.09711376, 300.08422093, 520.22607834,
#        524.53310623, 494.98685289, 305.10827232, 599.90016931,
#        395.27283914, 400.0120948 , 489.51804656, 405.1125414 ,
#        390.2384512 , 405.23413278, 298.91371371])

# %%
y_test
# Out:
# 12     195
# 53     320
# 78     315
# 8      530
# 28     275
# 81     465
# 73     300
# 15     251
# 101    325
# 34     323
# 76     410
# 9      195
# 123    455
# 107    385
# 106    455
# 137    355
# 22     288
# 70     490
# 26     300
# 102    520
# 90     525
# 138    495
# 89     305
# 150    600
# 11     395
# 63     400
# 114    490
# 66     405
# 69     390
# 46     405
# 36     299
# Name: Combat Power, dtype: int64

# %%
Y_predicted = linearRegression.predict(X_train)
from sklearn.metrics import accuracy_score

# %%
# accuracy_score(y_train,Y_predicted)
y_train.shape
# Out:
# (120,)

# %%
Y_predicted.shape
# Out:
# (120,)

# %%
accuracy_score(pd.Series.to_numpy(Y_predicted), y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-2a91174e201f> in <cell line: 1>()
# ----> 1 accuracy_score(pd.Series.to_numpy(Y_predicted), y_train)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in to_numpy(self, dtype, copy, na_value, **kwargs)
#     544             values[np.asanyarray(self.isna())] = na_value
#     545         else:
# --> 546             values = self._values
#     547
#     548         result = np.asarray(values, dtype=dtype)
#
# AttributeError: 'numpy.ndarray' object has no attribute '_values'

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
type(Y_predicted)
# Out:
# numpy.ndarray
